# %%
from pyspark.sql import SparkSession
from pyspark.ml.feature import VectorAssembler,VectorIndexer, OneHotEncoder, StringIndexer
from pyspark.ml.feature import Tokenizer, RegexTokenizer, StopWordsRemover, CountVectorizer, HashingTF, IDF
from pyspark.ml.linalg import Vector
from pyspark.ml.classification import RandomForestClassifier, RandomForestClassificationModel
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.sql.functions import lower, length, size

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.186.133:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://devenv:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc
# Out:
# <SparkContext master=spark://devenv:7077 appName=PySparkShell>

# %%
# Prepare data
data = spark.read.csv("hdfs://devenv/user/spark/spark_mllib_101/spam_detection/data/sms_messages_with_labels.csv",
                      inferSchema=True,
                      header=True)

# %%
# Preprocessing and feature engineering
feature_prep = data.select(lower(data["message"]).alias("message"), length(data["message"]).alias("length"), "label")

# %%
feature_prep = RegexTokenizer(inputCol="message", outputCol="words", pattern="\\W+").transform(feature_prep)

# %%
feature_prep = StopWordsRemover(inputCol='words',outputCol='stop_words_removed').transform(feature_prep)

# %%
feature_prep = HashingTF(inputCol="stop_words_removed", outputCol="hashing_tf", numFeatures=4000).transform(feature_prep)

# %%
feature_prep = IDF(inputCol="hashing_tf", outputCol="tf_idf").fit(feature_prep).transform(feature_prep)

# %%
feature_prep = StringIndexer(inputCol='label',outputCol='label_indexed').fit(feature_prep).transform(feature_prep)

# %%
feature_prep = VectorAssembler(inputCols=["tf_idf", "length"],
                               outputCol="features").transform(feature_prep)

# %%
final_data = feature_prep.select("label_indexed", "features")

# %%
# Split data into train and test sets
train_data, test_data = final_data.randomSplit([0.7,0.3])

# %%
# Model training
classifier = RandomForestClassifier(featuresCol="features", labelCol="label_indexed", numTrees=100, maxDepth=25)
model = classifier.fit(train_data)

# %%
# Transform the test data using the model to get predictions
predicted_test_data = model.transform(test_data)

# %%
evaluator_accuracy = MulticlassClassificationEvaluator(labelCol='label_indexed',
                                                           predictionCol='prediction', 
                                                           metricName='accuracy')
print("Accuracy: {}", evaluator_accuracy.evaluate(predicted_test_data))
# Out:
# Accuracy: {} 0.9580877537655533

# %%
# Save the model
model.save("hdfs://devenv/user/spark/spark_mllib_101/spam_detection/spam_classifier")

# %%
# Read the saved model
model = RandomForestClassificationModel.load("hdfs://devenv/user/spark/spark_mllib_101/spam_detection/spam_classifier")

# %%
# Predict some new records
# In real case, use VectorAssembler to transform df for features column

data = spark.read.csv("hdfs://devenv/user/spark/spark_mllib_101/spam_detection/data/sms_messages.csv",
                      inferSchema=True,
                      header=True)

# %%
# Preprocessing and feature engineering
feature_prep = data.select(lower(data["message"]).alias("message"), length(data["message"]).alias("length"))

feature_prep = RegexTokenizer(inputCol="message", outputCol="words", pattern="\\W+").transform(feature_prep)

feature_prep = StopWordsRemover(inputCol='words',outputCol='stop_words_removed').transform(feature_prep)

feature_prep = HashingTF(inputCol="stop_words_removed", outputCol="hashing_tf", numFeatures=4000).transform(feature_prep)

feature_prep = IDF(inputCol="hashing_tf", outputCol="tf_idf").fit(feature_prep).transform(feature_prep)

unclassified_final_data = VectorAssembler(inputCols=["tf_idf", "length"],
                                              outputCol="features").transform(feature_prep)

# %%
# Prediction
predicted_final_data = model.transform(unclassified_final_data)

# %%
result = predicted_final_data.select("message", "prediction")
result.show(1000)
# Out:
# +--------------------+----------+
# |             message|prediction|
# +--------------------+----------+
# |"speak only when ...|       0.0|
# |&lt;#&gt;  great ...|       0.0|
# |'wnevr i wana fal...|       0.0|
# |1apple/day=no doc...|       0.0|
# |7 lor... change 2...|       0.0|
# |7 wonders in my w...|       0.0|
# |:-( that's not v ...|       0.0|
# |a boy loved a gal...|       0.0|
# |a bit of ur smile...|       0.0|
# |a gram usually ru...|       0.0|
# |actually i decide...|       0.0|
# |ah you see. you h...|       0.0|
# |ahhh. work. i vag...|       0.0|
# |aight fuck it, i'...|       0.0|
# |aight ill get on ...|       0.0|
# |aight no rush, i'...|       0.0|
# |aight, i'll hit y...|       0.0|
# |aight, call me on...|       0.0|
# |aight, lemme know...|       0.0|
# |aiyah e rain like...|       0.0|
# |aiyar dun disturb...|       0.0|
# |alex says he's no...|       0.0|
# |all done? all han...|       0.0|
# |already one guy l...|       0.0|
# |alright, we're al...|       0.0|
# |also remember the...|       0.0|
# |am surfing online...|       0.0|
# |ambrith..madurai....|       0.0|
# |any pain on urina...|       0.0|
# |apart from the on...|       0.0|
# |ard 530 like dat ...|       0.0|
# |are you at work r...|       0.0|
# |are you still pla...|       0.0|
# |as i entered my c...|       0.0|
# |as per your reque...|       0.0|
# |as usual..iam fin...|       0.0|
# |at home watching ...|       0.0|
# |ay wana meet on s...|       0.0|
# |beautiful tomorro...|       0.0|
# |beautiful truth :...|       0.0|
# |better than bb. i...|       0.0|
# |better. made up f...|       0.0|
# |bishan lar nearer...|       0.0|
# |blank is blank. b...|       0.0|
# |brainless baby do...|       0.0|
# |busy here. trying...|       0.0|
# |but pls dont play...|       0.0|
# |cha quiteamuzing ...|       0.0|
# |come back to tamp...|       0.0|
# |call him and say ...|       0.0|
# |call me when you ...|       0.0|
# |call me. i m unab...|       0.0|
# |can come my room ...|       0.0|
# |can i meet ü at 5...|       0.0|
# |can you open the ...|       0.0|
# |can you pls pls s...|       0.0|
# |can you plz tell ...|       0.0|
# |can you say what ...|       0.0|
# |can you tell shol...|       0.0|
# |captain vijaykant...|       0.0|
# |carlos says we ca...|       0.0|
# |carlos'll be here...|       0.0|
# |convey my regards...|       0.0|
# |dad wanted to tal...|       0.0|
# |dear hero,i am le...|       0.0|
# |dear i am not den...|       0.0|
# |depends on where ...|       0.0|
# |desires- u going ...|       0.0|
# |dhoni have luck t...|       0.0|
# |did u find a sitt...|       0.0|
# |did u got that pe...|       0.0|
# |did you get any g...|       0.0|
# |did you stitch hi...|       0.0|
# |din i tell u jus ...|       0.0|
# |dnt worry...use i...|       0.0|
# |do whatever you w...|       0.0|
# |do you always cel...|       0.0|
# |do you think i ca...|       0.0|
# |doc prescribed me...|       0.0|
# |doing project w f...|       0.0|
# |don know..he is w...|       0.0|
# |don't worry, * is...|       0.0|
# |dont know support...|       0.0|
# |dont search love,...|       0.0|
# |dont think you ne...|       0.0|
# |dude im no longer...|       0.0|
# |dude ive been see...|       0.0|
# |dunno lei he neva...|       0.0|
# |dunno, my dad sai...|       0.0|
# |easy ah?sen got s...|       0.0|
# |edison has rightl...|       0.0|
# |eek that's a lot ...|       0.0|
# |everybody had fun...|       0.0|
# |excellent, i'll s...|       0.0|
# |fr'ndship is like...|       0.0|
# |fighting with the...|       0.0|
# |fighting with the...|       0.0|
# |   finish liao... u?|       0.0|
# |friendship poem: ...|       0.0|
# |full heat pa:-) i...|       0.0|
# |g says you never ...|       0.0|
# |goin to workout l...|       0.0|
# |good friends care...|       0.0|
# |good afternoon, m...|       0.0|
# |good afternoon, m...|       0.0|
# |good morning prin...|       0.0|
# |goodmorning, toda...|       0.0|
# |goodnight, sleep ...|       0.0|
# |great. p diddy is...|       0.0|
# |gud mrng dear hav...|       0.0|
# |gud ni8 dear..slp...|       0.0|
# |hi darlin how was...|       0.0|
# |ha ha ha good jok...|       0.0|
# |haha okay... toda...|       0.0|
# |haha... dont be a...|       0.0|
# |happy new year. h...|       0.0|
# |have a good eveni...|       0.0|
# |have you started ...|       0.0|
# |havent shopping n...|       0.0|
# |             havent.|       0.0|
# |he also knows abo...|       0.0|
# |he will, you guys...|       0.0|
# |height of confide...|       0.0|
# |hello beautiful r...|       0.0|
# |hello, as per req...|       0.0|
# |hello. no news on...|       0.0|
# |hey anyway i have...|       0.0|
# |hey are we going ...|       0.0|
# |hey babe, my frie...|       0.0|
# |hey hun-onbus goi...|       0.0|
# |hey i booked the ...|       0.0|
# |hey i will be lat...|       0.0|
# |hey i've booked t...|       0.0|
# |hey i've booked t...|       0.0|
# |hey mr whats the ...|       0.0|
# |hey r ü still onl...|       0.0|
# |hey what happen d...|       0.0|
# |hey, i missed you...|       0.0|
# |hey... what time ...|       0.0|
# |hey...great deal....|       0.0|
# |hi chachi tried c...|       0.0|
# |hi jon, pete here...|       0.0|
# |hi babe its me th...|       0.0|
# |hi dear we saw de...|       0.0|
# |hi msg me:)i'm in...|       0.0|
# |hi. hope ur day *...|       0.0|
# |hi. wk been ok - ...|       0.0|
# |his frens go then...|       0.0|
# |hmm ill have to t...|       0.0|
# |holy living chris...|       0.0|
# |honeybee said: *i...|       0.0|
# |hope ur head does...|       0.0|
# |hope you are feel...|       0.0|
# |hope you are havi...|       0.0|
# |hope you are not ...|       0.0|
# |how are you. its ...|       0.0|
# |how i noe... did ...|       0.0|
# |how much i gave t...|       0.0|
# |how much is black...|       0.0|
# |how to make a gir...|       0.0|
# |how was txting an...|       0.0|
# |how will i creep ...|       0.0|
# |     how's ur paper?|       0.0|
# |howz pain?hope u ...|       0.0|
# |huh so fast... da...|       0.0|
# |huh so late... fr...|       0.0|
# |huh so slow i tot...|       0.0|
# |huh? 6 also canno...|       0.0|
# |i have a date on ...|       0.0|
# |i am in tirupur. ...|       0.0|
# |i am taking half ...|       0.0|
# |i called and said...|       0.0|
# |i came hostel. i ...|       0.0|
# |i can make lasagn...|       0.0|
# |i cant pick the p...|       0.0|
# |i didnt get ur fu...|       0.0|
# |i dled 3d its ver...|       0.0|
# |i don't know jack...|       0.0|
# |i dont know why s...|       0.0|
# |i dont want to he...|       0.0|
# |i finished my lun...|       0.0|
# |i had askd u a qu...|       0.0|
# |i know you mood o...|       0.0|
# |i like dis sweate...|       0.0|
# |i love to cuddle!...|       0.0|
# |i love u 2 my lit...|       0.0|
# |i met you as a st...|       0.0|
# |i might come to k...|       0.0|
# |i miss you so muc...|       0.0|
# |i sent them. do y...|       0.0|
# |i think you shoul...|       0.0|
# |i to am looking f...|       0.0|
# |i want snow. it's...|       0.0|
# |i want to go to p...|       0.0|
# |i want to sent  &...|       0.0|
# |i was at bugis ju...|       0.0|
# |i went to project...|       0.0|
# |i will vote for w...|       0.0|
# |i'd say that's a ...|       0.0|
# |i'll see if i can...|       0.0|
# |i'm an actor. whe...|       0.0|
# |i'm going out to ...|       0.0|
# |i'm hungry buy sm...|       0.0|
# |i'm in town now s...|       0.0|
# |i'm leaving my ho...|       0.0|
# |i'm meeting darre...|       0.0|
# |i'm stuck in da m...|       0.0|
# |i'm thinking that...|       0.0|
# |i'm watching lotr...|       0.0|
# |i've been searchi...|       0.0|
# |i've been trying ...|       0.0|
# |i've sent my wife...|       0.0|
# |if i was i wasn't...|       0.0|
# |if e timing can, ...|       0.0|
# |if i said anythin...|       0.0|
# |if we hit it off,...|       0.0|
# |ill call you even...|       0.0|
# |in fact when do y...|       0.0|
# |in work now. goin...|       0.0|
# |is there any movi...|       0.0|
# |is there coming f...|       0.0|
# |is toshiba porteg...|       0.0|
# |is ur changes 2 d...|       0.0|
# |is ur paper in e ...|       0.0|
# |is xy going 4 e l...|       0.0|
# |isn't frnd a nece...|       0.0|
# |it didnt work aga...|       0.0|
# |it has everything...|       0.0|
# |it so happens tha...|       0.0|
# |its hard to belie...|       0.0|
# |its not the same ...|       0.0|
# |its sunny in cali...|       0.0|
# |i‘m going to try ...|       0.0|
# |jane babes not go...|       0.0|
# |jesus christ bitc...|       0.0|
# |just checking in ...|       0.0|
# |just got part not...|       0.0|
# |just nw i came to...|       0.0|
# |just sent you an ...|       0.0|
# |k actually can yo...|       0.0|
# |k still are you l...|       0.0|
# |k sure am in my r...|       0.0|
# |k, fyi i'm back i...|       0.0|
# |k. did you call m...|       0.0|
# |k...k...when will...|       0.0|
# |k..k..i'm also fi...|       0.0|
# |k.:)do it at even...|       0.0|
# |k.i did't see you...|       0.0|
# |k:)all the best:)...|       0.0|
# |kent vale lor... ...|       0.0|
# |ladies first and ...|       0.0|
# |lemme know when i...|       0.0|
# |let ur heart be u...|       0.0|
# |let me know how t...|       0.0|
# |life is more stri...|       0.0|
# |living is very si...|       0.0|
# |lmao but its so f...|       0.0|
# |lol i have to tak...|       0.0|
# |lol i know! hey s...|       0.0|
# |lol i know! they'...|       0.0|
# |lol for real. she...|       0.0|
# |lol no ouch but w...|       0.0|
# |lol yeah at this ...|       0.0|
# |lolnice. i went f...|       0.0|
# |maybe if you woke...|       0.0|
# |match started.ind...|       0.0|
# |may i call you la...|       0.0|
# |miles and smiles ...|       0.0|
# |missed your call ...|       0.0|
# |mm not entirely s...|       0.0|
# |mmm so yummy babe...|       0.0|
# |mum, hope you are...|       0.0|
# |must come later.....|       0.0|
# |my sister cleared...|       0.0|
# |nah man, my car i...|       0.0|
# |nah, i'm a perpet...|       0.0|
# |nah, wednesday. w...|       0.0|
# |nice. wait...shou...|       0.0|
# |night has ended f...|       0.0|
# |no i'm good for t...|       0.0|
# |no dice, art clas...|       0.0|
# |no management puz...|       0.0|
# |no messages on he...|       0.0|
# |no need to ke qi....|       0.0|
# |no shit, but i wa...|       0.0|
# |no, i was trying ...|       0.0|
# |no. she's current...|       0.0|
# |no:-)i got rumour...|       0.0|
# |nope thats fine. ...|       0.0|
# |nothing really, j...|       0.0|
# |     nothing. can...|       0.0|
# |now only i reache...|       0.0|
# |o i played smash ...|       0.0|
# |o we cant see if ...|       0.0|
# |ofcourse i also u...|       0.0|
# |oh all have to co...|       0.0|
# |oh oh... wasted.....|       0.0|
# |oh that was a for...|       0.0|
# |oh... kay... on s...|       0.0|
# |ok both our days....|       0.0|
# |ok cool. see ya t...|       0.0|
# |ok i found dis pi...|       0.0|
# |ok no prob. take ...|       0.0|
# |ok no prob... i'l...|       0.0|
# |ok no problem... ...|       0.0|
# |ok that would b l...|       0.0|
# |ok then i'll let ...|       0.0|
# |                 ok.|       0.0|
# |ok. how many shou...|       0.0|
# |ok. very good. it...|       0.0|
# |ok... let u noe w...|       0.0|
# |okay... i booked ...|       0.0|
# |                okie|       0.0|
# |                okie|       0.0|
# |      okie.. thanx..|       0.0|
# |omg how did u kno...|       0.0|
# |oooh bed ridden e...|       0.0|
# |oops - am at my m...|       0.0|
# |or u ask they all...|       0.0|
# |please protect yo...|       0.0|
# |prepare to be ple...|       0.0|
# |princess, i like ...|       0.0|
# |probably, want to...|       0.0|
# |purity of friends...|       0.0|
# |s....s...india go...|       0.0|
# |s...i will take m...|       0.0|
# |s.s:)i thinl role...|       0.0|
# |sad story of a ma...|       0.0|
# |same. wana plan a...|       0.0|
# |sary just need ti...|       0.0|
# |sat right? okay t...|       0.0|
# |save yourself the...|       0.0|
# |shall i start fro...|       0.0|
# |she went to atten...|       0.0|
# |sian... aft meeti...|       0.0|
# |sir, i am waiting...|       0.0|
# |so how are you re...|       0.0|
# |so its to be poki...|       0.0|
# |so lets make it s...|       0.0|
# |so what did the b...|       0.0|
# |solve d case : a ...|       0.0|
# |some are lasting ...|       0.0|
# |sorry . i will be...|       0.0|
# |sorry da thangam....|       0.0|
# |sorry da:)i was t...|       0.0|
# |sorry for the del...|       0.0|
# |sorry light turne...|       0.0|
# |sorry sent blank ...|       0.0|
# |sorry that took s...|       0.0|
# |sorry, i'll call ...|       0.0|
# |sorry, i'll call ...|       0.0|
# |sorry, i'll call ...|       0.0|
# |sorry, went to be...|       0.0|
# |sorry,in meeting ...|       0.0|
# |sounds better tha...|       0.0|
# |staff of placemen...|       0.0|
# |still chance ther...|       0.0|
# |still in customer...|       0.0|
# |still work going ...|       0.0|
# |takin a shower no...|       0.0|
# |tell me something...|       0.0|
# |thank god they ar...|       0.0|
# |thanks, i'll keep...|       0.0|
# |that seems unnece...|       0.0|
# |that seems unnece...|       0.0|
# |that would be gre...|       0.0|
# |that's cool he'll...|       0.0|
# |that's good, beca...|       0.0|
# |that's what i lov...|       0.0|
# |that's y we haf t...|       0.0|
# |the xmas story is...|       0.0|
# |the bus leaves at...|       0.0|
# |then dun wear jea...|       0.0|
# |then u ask darren...|       0.0|
# |then ü come n pic...|       0.0|
# |there's no point ...|       0.0|
# |these won't do. h...|       0.0|
# |this is all just ...|       0.0|
# |tick, tick, tick ...|       0.0|
# |to day class is t...|       0.0|
# |today i'm not wor...|       0.0|
# |tonight? yeah, i'...|       0.0|
# |total disappointm...|       0.0|
# |try to do somethi...|       0.0|
# |two teams waiting...|       0.0|
# |u will switch you...|       0.0|
# |u come n search t...|       0.0|
# |u ned to convince...|       0.0|
# |u still painting ...|       0.0|
# |ugh fuck it i'm r...|       0.0|
# |ujhhhhhhh compute...|       0.0|
# |umma. did she say...|       0.0|
# |unless it's a sit...|       0.0|
# |when the first st...|       0.0|
# |waiting for your ...|       0.0|
# |want to finally h...|       0.0|
# |water logging in ...|       0.0|
# |we are both fine....|       0.0|
# |we can go 4 e nor...|       0.0|
# |well good morning...|       0.0|
# |well i know z wil...|       0.0|
# |well there's stil...|       0.0|
# |well you told oth...|       0.0|
# |wen ur lovable bc...|       0.0|
# |what part of "don...|       0.0|
# |what r u cooking ...|       0.0|
# |what time you com...|       0.0|
# |what time you thi...|       0.0|
# |what time you thi...|       0.0|
# |what u mean u alm...|       0.0|
# |what was she look...|       0.0|
# |when u love someo...|       0.0|
# |where are you cal...|       0.0|
# |where is that one...|       0.0|
# |where you. what h...|       0.0|
# |why de. you looki...|       0.0|
# |will be office ar...|       0.0|
# |wish i were with ...|       0.0|
# |wow. i never real...|       0.0|
# |y ü wan to go the...|       0.0|
# |ya even those coo...|       0.0|
# |ya it came a whil...|       0.0|
# |ya just telling a...|       0.0|
# |ya very nice. . ....|       0.0|
# |yar but they say ...|       0.0|
# |yay! you better n...|       0.0|
# |yeah hopefully, i...|       0.0|
# |yeah my usual guy...|       0.0|
# |yeah why not, is ...|       0.0|
# |yeah, probably ea...|       0.0|
# |yeh. indians was ...|       0.0|
# |yep get with the ...|       0.0|
# |yes but can we me...|       0.0|
# |yes princess! i w...|       0.0|
# |yes see ya not on...|       0.0|
# |yes, princess. ar...|       0.0|
# |yes. i come to ny...|       0.0|
# |yes. that will be...|       0.0|
# |yes..but they sai...|       0.0|
# |yes..he is really...|       0.0|
# |yo im right by yo...|       0.0|
# |yo, any way we co...|       0.0|
# |you do your studi...|       0.0|
# |you only hate me....|       0.0|
# |you please give u...|       0.0|
# |you should know n...|       0.0|
# |you still at gran...|       0.0|
# |     you want to go?|       0.0|
# |you will be in th...|       0.0|
# |you've already go...|       0.0|
# |your opinion abou...|       0.0|
# |your opinion abou...|       0.0|
# |   yup bathe liao...|       0.0|
# |yup i shd haf ard...|       0.0|
# |     yup ok thanx...|       0.0|
# |yup. izzit still ...|       0.0|
# |yup... i havent b...|       0.0|
# |[…] anyway, many ...|       0.0|
# |cud u tell ppl im...|       0.0|
# |haha but no money...|       0.0|
# |hi my darlin im o...|       0.0|
# |that would be goo...|       0.0|
# |they released ano...|       0.0|
# |yeah, that's what...|       0.0|
# |07732584351 - rod...|       1.0|
# |22 days to kick o...|       1.0|
# |call 09095350301 ...|       0.0|
# |call freephone 08...|       0.0|
# |congratulations y...|       1.0|
# |congratulations u...|       1.0|
# |congratulations! ...|       1.0|
# |dear 0776xxxxxxx ...|       1.0|
# |december only! ha...|       1.0|
# |december only! ha...|       1.0|
# |do you want 750 a...|       1.0|
# |free for 1st week...|       1.0|
# |free2day sexy st ...|       1.0|
# |free>ringtone! re...|       1.0|
# |final chance! cla...|       1.0|
# |for ur chance to ...|       1.0|
# |for ur chance to ...|       1.0|
# |free msg. sorry, ...|       0.0|
# |freemsg: claim ur...|       1.0|
# |freemsg:feelin ki...|       1.0|
# |get 3 lions engla...|       1.0|
# |good luck! draw t...|       0.0|
# |gr8 poly tones 4 ...|       1.0|
# |great new offer -...|       1.0|
# |had your contract...|       1.0|
# |had your mobile 1...|       1.0|
# |here is your disc...|       1.0|
# |hi 07734396839 ib...|       1.0|
# |hi this is amy, w...|       0.0|
# |how come it takes...|       0.0|
# |january male sale...|       1.0|
# |last chance! clai...|       1.0|
# |moby pub quiz.win...|       1.0|
# |moby pub quiz.win...|       1.0|
# |natalja (25/f) is...|       1.0|
# |our dating servic...|       1.0|
# |rt-king pro video...|       1.0|
# |reminder: you hav...|       0.0|
# |sms services. for...|       1.0|
# |someonone you kno...|       1.0|
# |spook up your mob...|       1.0|
# |summers finally h...|       1.0|
# |t-mobile customer...|       1.0|
# |text & meet someo...|       0.0|
# |text82228>> get m...|       1.0|
# |think ur smart ? ...|       1.0|
# |this is the 2nd t...|       1.0|
# |todays vodafone n...|       1.0|
# |u have a secret a...|       1.0|
# |u have a secret a...|       1.0|
# |ur awarded a city...|       1.0|
# |urgent! we are tr...|       1.0|
# |urgent! your mobi...|       1.0|
# |urgent! your mobi...|       1.0|
# |ur balance is now...|       0.0|
# |ur cash-balance i...|       1.0|
# |ur cash-balance i...|       1.0|
# |ur cash-balance i...|       1.0|
# |urgent urgent! we...|       1.0|
# |win urgent! your ...|       1.0|
# |win a year supply...|       1.0|
# |win: we have a wi...|       1.0|
# |winner! as a valu...|       1.0|
# |we tried to conta...|       1.0|
# |welcome to uk-mob...|       1.0|
# |xmas offer! lates...|       1.0|
# |you ve won! your ...|       1.0|
# |you are a winner ...|       1.0|
# |you are being con...|       1.0|
# |you are being con...|       1.0|
# |you are guarantee...|       1.0|
# |you can donate £2...|       0.0|
# |you have won a gu...|       1.0|
# |you have an impor...|       0.0|
# |you have won a gu...|       1.0|
# |you won't believe...|       0.0|
# |from www.applause...|       1.0|
# |todays vodafone n...|       1.0|
# +--------------------+----------+
