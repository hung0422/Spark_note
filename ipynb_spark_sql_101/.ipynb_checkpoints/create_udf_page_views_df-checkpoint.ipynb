# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
# assume all work nodes have geoip2 installed
from geoip2.database import Reader

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.186.133:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.5</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://devenv:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
sc
# Out:
# <SparkContext master=spark://devenv:7077 appName=PySparkShell>

# %%
# (1) Define a normal Python function and match arguments to your UDF
reader = None

def ip2city_py(ip):
    global reader
    if reader is None:
        # assume all work nodes have mmdb installed in the following path
        reader = Reader("/home/spark/spark-2.4.5-bin-hadoop2.7/maxmind/GeoLite2-City.mmdb")
    try:
        response = reader.city(ip)
        city = response.city.name
        if city is None:
            return None
        return city
    except:
        return None

# %%
# (2) Register UDF function
ip2city = udf(ip2city_py, StringType())

# %%
# Use it
page_view = spark.read.csv("hdfs://devenv/user/spark/spark_sql_101/page_views/data",
                           sep="\t",
                           schema="logtime string, userid int, ip string, page string, \
                                  ref string, os string, os_ver string, agent string")

# %%
page_view_city = page_view.withColumn("city", ip2city("ip"))

# %%
stats_by_city_sorted = page_view_city.fillna("unknown", subset=["city"]) \
                                     .groupBy(col("city")) \
                                     .agg(count("*").alias("records"), countDistinct("userid").alias("UU count")) \
                                     .orderBy(col("records").desc())

# %%
stats_by_city_sorted.show(10000)
# Out:
# +--------------------+-------+--------+
# |                city|records|UU count|
# +--------------------+-------+--------+
# |             unknown|  19666|     924|
# |             Beijing|   1267|      87|
# |               Tokyo|    982|      70|
# |             Seattle|    539|      39|
# |            Dearborn|    481|      34|
# |           Guangzhou|    416|      26|
# |             Nanjing|    395|      24|
# |       Fort Huachuca|    385|      26|
# |             Houston|    355|      24|
# |         Los Angeles|    335|      23|
# |             Toronto|    329|      20|
# |            Shenzhen|    308|      20|
# |          Washington|    293|      20|
# |          Montgomery|    284|      20|
# |               Xi'an|    277|      20|
# |              Taipei|    276|      20|
# |            San Jose|    271|      20|
# |             Chicago|    255|      20|
# |            New York|    235|      19|
# |               Seoul|    230|      16|
# |              Baotou|    221|      14|
# |              Austin|    211|      16|
# |            Hangzhou|    202|      16|
# |           Bengaluru|    200|      14|
# |           Zhengzhou|    199|      16|
# |            Shanghai|    199|      16|
# |              Dallas|    196|      15|
# |               Osaka|    185|      12|
# |               Miami|    173|      10|
# |              Moscow|    172|      12|
# |              Newark|    172|      12|
# |         Bentonville|    169|      11|
# |            St Louis|    165|      12|
# |              Boston|    159|      12|
# |           Amsterdam|    158|      12|
# |            Grenoble|    158|      11|
# |             Atlanta|    156|      12|
# |             Ashburn|    156|      12|
# |      Virginia Beach|    152|      12|
# |              Ningbo|    150|      12|
# |               Hanoi|    150|      12|
# |              Vienna|    132|      11|
# |        Philadelphia|    131|       8|
# |           La Crosse|    131|       8|
# |            Kingston|    130|       8|
# |           Gorontalo|    130|       8|
# |         Albertville|    129|       8|
# |               Busan|    127|       8|
# |           San Diego|    127|       7|
# |        Buenos Aires|    126|       8|
# |           New Haven|    125|       8|
# |          Cincinnati|    123|       8|
# |             Calgary|    121|       8|
# |              Duluth|    120|       8|
# |           Englewood|    118|       8|
# |            Changsha|    118|       8|
# |               Chiba|    116|       8|
# |             Clayton|    115|       8|
# |             Poltava|    115|       8|
# |          Woodbridge|    114|       7|
# |           Las Vegas|    113|       8|
# |          Saint Paul|    113|       7|
# |              Mumbai|    112|       8|
# |           São Paulo|    112|       8|
# |              Durham|    110|       8|
# |           Chongqing|    110|       7|
# |               Jinan|    110|       7|
# |        Redwood City|    108|       8|
# |           Cape Town|    107|       8|
# |           Bucharest|    106|       8|
# |           Cupertino|    106|       7|
# |            Milpitas|    105|       8|
# |          Sacramento|    105|       8|
# |             Kunming|    105|       8|
# |            Oakville|    103|       8|
# |                Kiev|    102|       8|
# |               Hefei|    102|       6|
# |            Boardman|    102|       8|
# |             Gwangju|    101|       6|
# |           Charlotte|    101|       7|
# |          Sagamihara|    100|       8|
# |           Cambridge|     97|       7|
# |     Fort Lauderdale|     97|       8|
# |         Mexico City|     91|       8|
# |       St Petersburg|     88|       8|
# |            Franeker|     84|       4|
# |           Leicester|     81|       4|
# |             Leerdam|     80|       4|
# |          Pittsburgh|     78|       8|
# |             Phoenix|     77|       4|
# |              Ashdod|     75|       4|
# |    Colorado Springs|     75|       4|
# |               Wuhan|     74|       3|
# |             Jakarta|     74|       4|
# |           Roseville|     73|       4|
# |              Hadano|     72|       4|
# |       Lamezia Terme|     72|       4|
# |          Batu Caves|     71|       4|
# |               Tomsk|     71|       3|
# |            Pavlodar|     71|       4|
# |          Ocean City|     71|       4|
# |            Torrance|     71|       4|
# |           Bryn Mawr|     71|       4|
# |       Mountain View|     71|       4|
# |              Prague|     70|       4|
# |              Roding|     70|       3|
# |             Ban Pao|     70|       4|
# | San Juan del Puerto|     70|       4|
# |         Wittenberge|     70|       4|
# |            Elbistan|     69|       4|
# |     Medina de Pomar|     69|       4|
# |          Parsippany|     68|       4|
# |            Stolwijk|     68|       4|
# |           Melbourne|     68|       4|
# |                 Apt|     68|       4|
# |              Cannes|     68|       4|
# |              Quezon|     67|       3|
# |       Kleinkarlbach|     67|       4|
# |        Schardenberg|     67|       3|
# |      Crawfordsville|     67|       4|
# |             Oakland|     66|       4|
# |          Skofja Vas|     66|       4|
# |               Cairo|     66|       4|
# |             Clinton|     66|       3|
# |             Waltham|     66|       4|
# |   Bergen auf Ruegen|     66|       4|
# |            Bradford|     66|       4|
# |  Erbach im Odenwald|     66|       4|
# |             Lisburn|     65|       4|
# |         Hedgesville|     65|       4|
# |           Zhongshan|     65|       4|
# |          New Bremen|     65|       4|
# |            Akishima|     65|       4|
# |        Kristiansand|     65|       4|
# |          Upper Hutt|     65|       4|
# |              Orange|     65|       4|
# |            Columbus|     65|       4|
# |             Vologda|     65|       4|
# |           Araçatuba|     65|       4|
# |              Assago|     64|       4|
# |           Karlsruhe|     64|       4|
# |               Akron|     64|       4|
# |           Mytishchi|     64|       4|
# |            Winnipeg|     64|       4|
# |               Trier|     64|       4|
# |Rødovre Municipality|     64|       4|
# |            Stafford|     64|       4|
# |             Cologne|     64|       4|
# |         Beauharnois|     64|       4|
# |                Koga|     63|       3|
# |Saint-Philbert-de...|     63|       3|
# |             Danbury|     63|       4|
# |              Arcata|     63|       4|
# |         Lake Placid|     63|       4|
# |              Leiden|     63|       4|
# |            Wellston|     63|       3|
# |          Binghamton|     63|       4|
# |            Nanterre|     63|       4|
# |              Québec|     63|       4|
# |           Flagstaff|     63|       4|
# |         Centreville|     63|       4|
# |             Siliana|     63|       4|
# |             Riviere|     63|       4|
# |           Sundhouse|     62|       4|
# |             Kolkata|     62|       4|
# |     Villa Ballester|     62|       4|
# |              Atsugi|     62|       4|
# |            Florence|     62|       4|
# |          Matadepera|     62|       4|
# |            Langerak|     62|       4|
# |              Halden|     62|       4|
# |           Sunnyvale|     62|       4|
# |            Shenyang|     62|       4|
# |               Saijo|     62|       4|
# |             Liminka|     62|       4|
# |         Al Mansurah|     62|       4|
# |           Krasnodar|     62|       4|
# |         North Lakes|     61|       3|
# |       Pinellas Park|     61|       4|
# |            Jackmans|     61|       4|
# |           Bray Park|     61|       4|
# |             Straume|     61|       4|
# |          Pleasanton|     61|       4|
# |            Tel Aviv|     61|       4|
# |               Pinto|     61|       4|
# |            Asunción|     61|       4|
# |             Kogarah|     61|       3|
# |             Seville|     61|       4|
# |              Riyadh|     61|       4|
# |          Kwai Chung|     61|       4|
# |            Kawasaki|     61|       3|
# |              Poznan|     61|       4|
# |                Alba|     60|       4|
# |             Caracas|     60|       4|
# |              Canton|     60|       4|
# |               Ogden|     60|       4|
# |           Dobrovice|     60|       4|
# |          Altagracia|     60|       4|
# |             Ravenna|     60|       4|
# |            Belgorod|     60|       4|
# |              Witten|     60|       4|
# |      Denham Springs|     60|       3|
# |             Machida|     60|       4|
# |   Alcalá de Henares|     59|       4|
# |               Ramon|     59|       4|
# |          Louisville|     59|       4|
# |             Dunedin|     59|       4|
# |               Maipu|     59|       4|
# |         Voskresensk|     59|       4|
# |             Croydon|     59|       4|
# |        Hod HaSharon|     59|       3|
# |           Koshigaya|     59|       4|
# |         Baguio City|     59|       3|
# |                 Jar|     59|       4|
# |        Indianapolis|     59|       3|
# |            Lewisham|     59|       4|
# |             Olsztyn|     58|       4|
# |         Little Rock|     58|       4|
# |           Baia Mare|     58|       4|
# |               Arras|     58|       4|
# |             Malatya|     58|       4|
# |         Orange Park|     58|       4|
# |            Portland|     58|       4|
# |            Pretoria|     58|       4|
# |         Hwaseong-si|     58|       3|
# |            Santiago|     58|       4|
# |               Rhede|     58|       4|
# |              Buftea|     57|       4|
# |            Alcester|     57|       4|
# |                Doha|     57|       4|
# |          Nottingham|     57|       4|
# |             Conover|     57|       4|
# |              Ankara|     57|       4|
# |       Jamaica Plain|     57|       4|
# |              Berlin|     57|       4|
# |         Almere Stad|     57|       4|
# |                Graz|     57|       4|
# |             Madison|     57|       4|
# |             Münster|     57|       4|
# |           Northport|     57|       4|
# |               Wigan|     57|       4|
# |    Campulung Muscel|     57|       4|
# |          Moordrecht|     57|       3|
# |             Brovary|     56|       3|
# |        Hilvarenbeek|     56|       4|
# |              Gimhae|     56|       4|
# |    Viana do Castelo|     56|       4|
# |            Tatarusi|     56|       4|
# |                 Ome|     56|       4|
# |    Canal Winchester|     56|       4|
# |            Shizuoka|     56|       4|
# |          Coraopolis|     56|       4|
# |            Berkeley|     56|       4|
# |       Chestnut Hill|     56|       4|
# |Sainte-Geneviève-...|     56|       3|
# |               Porto|     56|       4|
# |          Toms River|     56|       4|
# |          Ingolstadt|     56|       4|
# |                Uden|     56|       4|
# |                Lyon|     56|       4|
# |                Erie|     56|       4|
# |             Redmond|     56|       4|
# |          Gothenburg|     55|       4|
# |        West Chester|     55|       4|
# |               Tibro|     55|       4|
# |            Edmonton|     55|       3|
# |           Singapore|     55|       3|
# |            Montreal|     55|       4|
# |             Donetsk|     55|       3|
# |           Islington|     55|       4|
# |              Tehran|     55|       4|
# |             Molalla|     55|       4|
# |            Kapellen|     55|       4|
# |             Andover|     55|       3|
# |              Dayton|     55|       4|
# |          Middlebury|     55|       4|
# |             Anseong|     55|       3|
# |              Harbin|     54|       4|
# |               Rayne|     54|       3|
# |    Roche-la-Moliere|     54|       4|
# |        Thessaloniki|     54|       4|
# |     Lomas de Zamora|     54|       4|
# |         New Orleans|     54|       3|
# |         Tallahassee|     54|       4|
# |            Bordeaux|     54|       4|
# |         Mississauga|     54|       4|
# |          Greifswald|     54|       4|
# |             Wichita|     54|       3|
# |           Amneville|     54|       4|
# |           Darmstadt|     54|       3|
# |          San Marcos|     54|       4|
# |             Colombo|     54|       4|
# |            Kilkenny|     54|       4|
# |         Albuquerque|     54|       4|
# |            Palatine|     54|       4|
# |          Alcobendas|     54|       4|
# |San Pedro Garza G...|     54|       3|
# |               Dubai|     54|       4|
# |               Cadiz|     54|       4|
# |         Nyiregyhaza|     53|       4|
# |             Forbach|     53|       3|
# |              Denver|     53|       4|
# |              Madrid|     53|       4|
# |           Stuttgart|     53|       4|
# |       New Hyde Park|     53|       4|
# |              Tucson|     53|       4|
# |                Kobe|     53|       4|
# |          Labytnangi|     53|       3|
# |           Stockholm|     53|       4|
# |             Wissous|     53|       4|
# |              Xuzhou|     52|       4|
# |               Assen|     52|       4|
# |           Lexington|     52|       4|
# |            Waterloo|     52|       4|
# |              Fuzhou|     52|       3|
# |              Dublin|     52|       4|
# |             Pescara|     52|       4|
# |          Cape Coral|     52|       4|
# |              Mobile|     52|       3|
# |           Tres Rios|     52|       4|
# |              Holeby|     52|       4|
# |           Livermore|     52|       4|
# |           Khanh Hoa|     52|       4|
# |        Eden Prairie|     52|       4|
# |           Funabashi|     52|       4|
# |              Warsaw|     52|       4|
# |        Russellville|     52|       3|
# |             Bizanos|     52|       3|
# |             Nanning|     52|       4|
# |           Chuncheon|     51|       4|
# |Thanh Pho Thai Ng...|     51|       3|
# |         Santa Clara|     51|       4|
# |             Alameda|     51|       4|
# |       Draa el Mizan|     51|       4|
# |              London|     51|       3|
# |            Matamata|     51|       4|
# |       Torredembarra|     51|       4|
# |            Comanche|     51|       4|
# |       Moncks Corner|     51|       4|
# |               Leeds|     51|       3|
# |             Reading|     51|       4|
# |         Belchertown|     50|       4|
# |           Ann Arbor|     50|       4|
# |               Essen|     50|       4|
# |Vila Nova de Fama...|     50|       4|
# |                Riga|     50|       4|
# |              Sendai|     50|       3|
# |             Matsudo|     50|       4|
# |               Tempe|     50|       4|
# |             Utrecht|     50|       3|
# |               Soddy|     50|       4|
# |             Kętrzyn|     50|       4|
# |        Mons-Boubert|     50|       4|
# |            Almancil|     50|       4|
# |            Brooklyn|     49|       4|
# |             Mongkok|     49|       4|
# |          Greenville|     49|       4|
# |            Cernilov|     49|       3|
# |          Landerneau|     49|       3|
# |             Hampton|     49|       4|
# |               Bowie|     49|       4|
# |               Sofia|     49|       4|
# | Oloron-Sainte-Marie|     49|       4|
# |              Leland|     49|       3|
# |                 Pau|     49|       4|
# |             Bottrop|     49|       3|
# |         Stourbridge|     49|       4|
# |          Huntsville|     49|       3|
# |             Dundalk|     48|       4|
# |           Vancouver|     48|       3|
# |            Haeundae|     48|       4|
# |          Nonthaburi|     48|       4|
# |          Thanyaburi|     48|       4|
# |              Arucas|     48|       4|
# |              Lleida|     48|       4|
# |                Oslo|     47|       4|
# |                Rome|     47|       4|
# |             Orillia|     47|       4|
# |            Overijse|     47|       4|
# |   Vila Nova de Gaia|     47|       4|
# |      Port Charlotte|     47|       4|
# |           Palo Alto|     47|       3|
# |            Wanstead|     47|       4|
# |             Marlton|     46|       3|
# |            Surabaya|     46|       3|
# |        Poughkeepsie|     46|       3|
# |               Delhi|     46|       4|
# |         Kansas City|     46|       4|
# |         Demir Hisar|     46|       4|
# |         Kailua-Kona|     46|       4|
# |            Monrovia|     46|       4|
# |            Hamilton|     46|       4|
# |              Lahore|     46|       4|
# |            Botoşani|     45|       4|
# |             Juelich|     45|       4|
# |         Westervoort|     45|       4|
# |              Krakow|     45|       4|
# |             Andelst|     44|       3|
# |              Fréjus|     44|       4|
# |             Ashland|     44|       4|
# |            Yokosuka|     44|       3|
# |         San Antonio|     44|       4|
# |           Nashville|     44|       3|
# |        Edwardsville|     44|       4|
# |         Chiayi City|     44|       4|
# |           Barcelona|     44|       4|
# |     Crystal Springs|     44|       4|
# |         Bloomington|     44|       4|
# |             Itajuba|     44|       4|
# |             Lorgues|     44|       4|
# |               Valby|     44|       4|
# |     Rowland Heights|     43|       4|
# |         Koyang-dong|     43|       4|
# |              Fabius|     43|       4|
# |            Yelabuga|     43|       4|
# |             Angarsk|     42|       4|
# |           Schofield|     42|       4|
# |               Oryol|     42|       4|
# |              Suqian|     42|       4|
# |               Hebei|     41|       4|
# |             Herndon|     40|       4|
# |     North Vancouver|     40|       4|
# |       Oklahoma City|     40|       4|
# |           Northmead|     39|       3|
# |          Phnom Penh|     39|       4|
# |         Bucaramanga|     38|       3|
# |         Summerville|     38|       4|
# |              Sydney|     38|       4|
# |          Richardson|     37|       4|
# +--------------------+-------+--------+
